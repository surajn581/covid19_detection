# %%
from shutil import copyfile
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import shutil

# %%
src = 'D:/Downloads/gta5/Compressed/covid_19_dataset/'
dst = 'D:/Downloads/gta5/Compressed/covid_19_dataset_sorted/data/'

# %%
data_details = pd.read_csv(src+'labels.csv')
data_details = data_details.sample(frac = 1).reset_index(drop=True)

# %%
data_details.head()
# Out:
#                                                image                   label  \
# 0                         Radiography/NORMAL-488.png           non-infection
# 1                        Radiography/NORMAL-1025.png           non-infection
# 2               Radiography/Viral Pneumonia-1152.png  non-covid-19 pneumonia
# 3      covid_chestxray/296_2020_4584_Fig2_HTML-b.png      covid-19 pneumonia
# 4  covid_chestxray/1e64990d1b40c1758a2aaa9c7f7a85...  non-covid-19 pneumonia
#
#     View
# 0  Front
# 1  Front
# 2  Front
# 3  Front
# 4  Front

# %%
print(data_details.View.unique())
print(data_details.label.unique())
# Out:
# ['Front' 'L' 'Axial']
# ['non-infection' 'non-covid-19 pneumonia' 'covid-19 pneumonia']

# %%
data_details.image[0].replace('/','-')
# Out:
# 'Radiography-NORMAL-488.png'

# %%
img = cv2.imread(src+data_details.image[0])
plt.imshow(img)

# %%
for i in range(len(data_details)):
    if data_details.View[i] == 'Front':
        if data_details.label[i] == 'non-infection':
            try:
                copyfile(src+data_details.image[i], dst+'healthy/'+data_details.image[i].replace('/','-'))
            except:
                print(i, ' File error')
        elif data_details.label[i] == 'covid-19 pneumonia':
            try:
                copyfile(src+data_details.image[i], dst+'covid/'+data_details.image[i].replace('/','-'))
            except:
                print(i, ' File error')
        elif data_details.label[i] == 'non-covid-19 pneumonia':
            try:
                copyfile(src+data_details.image[i], dst+'noncovid/'+data_details.image[i].replace('/','-'))
            except:
                print(i, ' File error')
        else:
            print('No conditions matched')
    else:
        print('View is not front')
    print(i, ' is done')
print('Copy Complete')
# Out:
# 0  is done
# 1  is done
# 2  is done
# 3  is done
# 4  is done
# 5  is done
# 6  is done
# 7  is done
# 8  is done
# 9  is done
# 10  is done
# 11  is done
# 12  is done
# 13  is done
# 14  is done
# 15  is done
# 16  is done
# 17  is done
# 18  is done
# 19  is done
# 20  is done
# 21  is done
# 22  is done
# 23  is done
# 24  is done
# 25  is done
# 26  is done
# 27  is done
# 28  is done
# 29  is done
# 30  is done
# 31  is done
# 32  is done
# 33  is done
# 34  is done
# 35  is done
# 36  is done
# 37  is done
# 38  is done
# 39  is done
# 40  is done
# 41  is done
# 42  is done
# 43  is done
# 44  is done
# 45  is done
# 46  is done
# 47  is done
# 48  is done
# 49  is done
# 50  is done
# 51  is done
# 52  is done
# 53  is done
# 54  is done
# 55  is done
# 56  is done
# 57  is done
# 58  is done
# 59  is done
# 60  is done
# 61  is done
# 62  is done
# 63  is done
# 64  is done
# 65  is done
# 66  is done
# 67  is done
# 68  is done
# 69  is done
# 70  is done
# 71  is done
# 72  is done
# 73  is done
# 74  is done
# 75  is done
# 76  is done
# 77  is done
# 78  is done
# 79  is done
# 80  is done
# 81  is done
# 82  is done
# 83  is done
# 84  is done
# 85  is done
# 86  is done
# 87  is done
# 88  is done
# 89  is done
# 90  is done
# 91  is done
# 92  is done
# 93  is done
# 94  is done
# 95  is done
# 96  is done
# 97  is done
# 98  is done
# 99  is done
# 100  is done
# 101  is done
# 102  is done
# 103  is done
# 104  is done
# 105  is done
# 106  is done
# 107  is done
# 108  is done
# 109  is done
# 110  is done
# 111  is done
# 112  is done
# 113  is done
# 114  is done
# 115  is done
# 116  is done
# 117  is done
# 118  is done
# 119  is done
# 120  is done
# 121  is done
# 122  is done
# View is not front
# 123  is done
# 124  is done
# 125  is done
# 126  is done
# 127  is done
# 128  is done
# 129  is done
# 130  is done
# 131  is done
# View is not front
# 132  is done
# 133  is done
# 134  is done
# 135  is done
# 136  is done
# 137  is done
# 138  is done
# 139  is done
# 140  is done
# 141  is done
# View is not front
# 142  is done
# View is not front
# 143  is done
# 144  is done
# 145  is done
# 146  is done
# 147  is done
# 148  is done
# 149  is done
# 150  is done
# 151  is done
# 152  is done
# 153  is done
# 154  is done
# 155  is done
# 156  is done
# 157  is done
# 158  is done
# 159  is done
# 160  is done
# 161  is done
# 162  is done
# 163  is done
# 164  is done
# 165  is done
# 166  is done
# 167  is done
# 168  is done
# 169  is done
# 170  is done
# 171  is done
# 172  is done
# 173  is done
# 174  is done
# 175  is done
# 176  is done
# 177  is done
# 178  is done
# 179  is done
# 180  is done
# 181  is done
# 182  is done
# 183  is done
# 184  is done
# 185  is done
# 186  is done
# 187  is done
# 188  is done
# 189  is done
# 190  is done
# 191  is done
# 192  is done
# 193  is done
# 194  is done
# 195  is done
# 196  is done
# 197  is done
# 198  is done
# 199  is done
# 200  is done
# 201  is done
# 202  is done
# 203  is done
# 204  is done
# 205  is done
# 206  is done
# 207  is done
# 208  is done
# 209  is done
# 210  is done
# 211  is done
# 212  is done
# 213  is done
# 214  is done
# 215  is done
# 216  is done
# 217  is done
# 218  is done
# 219  is done
# 220  is done
# 221  is done
# 222  is done
# 223  is done
# 224  is done
# 225  is done
# 226  is done
# 227  is done
# 228  is done
# View is not front
# 229  is done
# 230  is done
# 231  is done
# 232  is done
# 233  is done
# 234  is done
# 235  is done
# 236  is done
# View is not front
# 237  is done
# 238  is done
# 239  is done
# 240  is done
# 241  is done
# 242  is done
# 243  is done
# 244  is done
# 245  is done
# 246  is done
# 247  is done
# 248  is done
# 249  is done
# 250  is done
# 251  is done
# 252  is done
# 253  is done
# 254  is done
# 255  is done
# 256  is done
# 257  is done
# 258  is done
# 259  is done
# 260  is done
# 261  is done
# 262  File error
# 262  is done
# 263  is done
# 264  is done
# 265  is done
# 266  is done
# 267  is done
# 268  is done
# 269  is done
# 270  is done
# 271  is done
# 272  is done
# 273  is done
# 274  is done
# 275  is done
# 276  is done
# 277  is done
# 278  is done
# 279  is done
# 280  is done
# 281  is done
# 282  is done
# 283  is done
# 284  is done
# 285  is done
# 286  is done
# 287  is done
# 288  is done
# 289  is done
# 290  is done
# 291  is done
# 292  is done
# 293  is done
# 294  is done
# 295  is done
# 296  is done
# 297  is done
# 298  is done
# 299  is done
# 300  is done
# 301  is done
# 302  is done
# 303  is done
# 304  is done
# 305  is done
# 306  is done
# 307  is done
# 308  is done
# 309  is done
# 310  is done
# 311  is done
# 312  is done
# 313  is done
# 314  is done
# 315  is done
# 316  is done
# 317  is done
# 318  is done
# View is not front
# 319  is done
# 320  is done
# 321  is done
# 322  is done
# 323  is done
# 324  is done
# 325  is done
# 326  is done
# View is not front
# 327  is done
# 328  is done
# 329  is done
# 330  is done
# 331  is done
# 332  is done
# 333  is done
# 334  is done
# 335  is done
# 336  is done
# 337  is done
# 338  is done
# 339  is done
# 340  is done
# 341  is done
# 342  is done
# 343  is done
# 344  is done
# 345  is done
# 346  is done
# 347  is done
# 348  is done
# 349  is done
# 350  is done
# 351  is done
# 352  is done
# 353  is done
# 354  is done
# 355  is done
# 356  is done
# 357  is done
# 358  is done
# 359  is done
# 360  is done
# 361  is done
# 362  is done
# 363  is done
# 364  is done
# View is not front
# 365  is done
# 366  is done
# 367  is done
# 368  is done
# 369  is done
# 370  is done
# 371  is done
# 372  is done
# 373  is done
# 374  is done
# 375  is done
# 376  is done
# View is not front
# 377  is done
# 378  is done
# 379  is done
# 380  is done
# 381  is done
# 382  is done
# 383  is done
# 384  is done
# 385  is done
# 386  is done
# 387  is done
# 388  is done
# 389  is done
# 390  is done
# 391  is done
# 392  is done
# 393  is done
# 394  is done
# 395  is done
# 396  is done
# 397  is done
# 398  is done
# 399  is done
# 400  is done
# 401  is done
# 402  is done
# 403  is done
# 404  is done
# 405  is done
# 406  is done
# 407  is done
# 408  is done
# View is not front
# 409  is done
# 410  is done
# 411  is done
# 412  is done
# 413  is done
# 414  is done
# 415  is done
# 416  is done
# 417  is done
# 418  is done
# 419  is done
# 420  is done
# 421  is done
# 422  is done
# 423  is done
# 424  is done
# 425  is done
# 426  is done
# 427  is done
# 428  is done
# 429  is done
# 430  is done
# 431  is done
# 432  is done
# 433  is done
# 434  is done
# 435  is done
# 436  is done
# 437  is done
# 438  is done
# 439  is done
# 440  is done
# 441  is done
# 442  is done
# 443  is done
# 444  is done
# 445  is done
# 446  is done
# 447  is done
# 448  is done
# 449  is done
# 450  is done
# View is not front
# 451  is done
# 452  is done
# 453  is done
# 454  is done
# 455  is done
# 456  is done
# 457  is done
# 458  is done
# 459  is done
# 460  is done
# 461  is done
# 462  is done
# 463  is done
# 464  is done
# 465  is done
# 466  is done
# 467  is done
# 468  is done
# 469  is done
# 470  is done
# 471  is done
# 472  is done
# 473  is done
# 474  is done
# View is not front
# 475  is done
# 476  is done
# 477  is done
# 478  is done
# 479  is done
# 480  is done
# 481  is done
# 482  is done
# 483  is done
# 484  is done
# 485  is done
# 486  is done
# 487  is done
# 488  is done
# 489  is done
# 490  is done
# 491  is done
# 492  is done
# 493  is done
# 494  is done
# 495  is done
# 496  is done
# 497  is done
# 498  is done
# 499  is done
# 500  is done
# 501  is done
# 502  is done
# 503  is done
# 504  is done
# 505  is done
# 506  is done
# 507  is done
# 508  is done
# 509  is done
# 510  is done
# 511  is done
# 512  is done
# 513  is done
# 514  is done
# View is not front
# 515  is done
# 516  is done
# 517  is done
# 518  is done
# 519  is done
# 520  is done
# View is not front
# 521  is done
# 522  is done
# 523  is done
# 524  is done
# 525  is done
# 526  is done
# 527  is done
# 528  is done
# 529  is done
# 530  is done
# 531  is done
# 532  is done
# 533  is done
# 534  is done
# 535  is done
# 536  is done
# 537  is done
# View is not front
# 538  is done
# 539  is done
# 540  is done
# 541  is done
# 542  is done
# 543  is done
# 544  is done
# 545  is done
# View is not front
# 546  is done
# 547  is done
# 548  is done
# 549  is done
# 550  is done
# 551  is done
# 552  is done
# 553  is done
# View is not front
# 554  is done
# 555  is done
# 556  is done
# 557  is done
# 558  is done
# 559  is done
# 560  is done
# 561  is done
# 562  is done
# 563  is done
# 564  is done
# 565  is done
# 566  is done
# 567  is done
# 568  is done
# 569  is done
# 570  is done
# 571  is done
# 572  is done
# 573  is done
# 574  is done
# 575  is done
# 576  is done
# 577  is done
# 578  is done
# 579  is done
# 580  is done
# 581  is done
# 582  is done
# 583  is done
# 584  is done
# 585  is done
# 586  is done
# 587  is done
# 588  is done
# 589  is done
# 590  is done
# 591  is done
# 592  is done
# 593  is done
# 594  is done
# 595  is done
# 596  is done
# 597  is done
# 598  is done
# 599  is done
# 600  is done
# 601  is done
# 602  is done
# 603  is done
# 604  is done
# 605  is done
# 606  is done
# 607  is done
# 608  is done
# 609  is done
# 610  is done
# 611  is done
# 612  is done
# 613  is done
# 614  is done
# 615  is done
# 616  is done
# 617  is done
# 618  is done
# 619  is done
# 620  is done
# 621  is done
# 622  is done
# 623  is done
# 624  is done
# View is not front
# 625  is done
# 626  is done
# View is not front
# 627  is done
# 628  is done
# 629  is done
# 630  is done
# 631  is done
# 632  is done
# 633  is done
# 634  is done
# 635  is done
# 636  is done
# 637  is done
# View is not front
# 638  is done
# 639  is done
# 640  is done
# 641  is done
# 642  is done
# 643  is done
# 644  is done
# 645  is done
# 646  is done
# 647  is done
# 648  is done
# 649  is done
# 650  is done
# 651  is done
# 652  is done
# 653  is done
# 654  is done
# 655  is done
# 656  is done
# 657  is done
# 658  is done
# 659  is done
# 660  is done
# 661  is done
# 662  is done
# 663  is done
# 664  is done
# 665  is done
# 666  is done
# 667  is done
# 668  is done
# 669  is done
# 670  is done
# 671  is done
# 672  is done
# 673  is done
# 674  is done
# 675  is done
# 676  is done
# 677  is done
# 678  is done
# 679  is done
# 680  is done
# 681  is done
# 682  is done
# 683  is done
# 684  is done
# 685  is done
# 686  is done
# 687  is done
# 688  is done
# 689  is done
# 690  is done
# 691  is done
# 692  is done
# 693  is done
# 694  is done
# 695  is done
# 696  is done
# 697  is done
# 698  is done
# 699  is done
# View is not front
# 700  is done
# 701  is done
# 702  is done
# 703  is done
# 704  is done
# 705  is done
# 706  is done
# 707  is done
# View is not front
# 708  is done
# 709  is done
# 710  is done
# 711  is done
# 712  is done
# 713  is done
# 714  is done
# 715  is done
# 716  is done
# 717  is done
# 718  is done
# 719  is done
# 720  is done
# 721  is done
# 722  is done
# 723  is done
# 724  is done
# 725  is done
# 726  is done
# 727  is done
# 728  is done
# 729  is done
# 730  is done
# 731  is done
# 732  is done
# 733  is done
# 734  is done
# 735  is done
# 736  is done
# 737  is done
# 738  is done
# 739  is done
# 740  is done
# 741  is done
# 742  is done
# 743  is done
# 744  is done
# 745  is done
# 746  is done
# 747  is done
# 748  is done
# 749  is done
# 750  is done
# 751  is done
# 752  is done
# 753  is done
# 754  is done
# 755  is done
# 756  is done
# 757  is done
# 758  is done
# 759  is done
# 760  is done
# 761  is done
# 762  is done
# View is not front
# 763  is done
# 764  is done
# 765  is done
# 766  is done
# 767  is done
# 768  is done
# 769  is done
# 770  is done
# 771  is done
# 772  is done
# View is not front
# 773  is done
# 774  is done
# 775  is done
# 776  is done
# 777  is done
# View is not front
# 778  is done
# 779  is done
# 780  is done
# 781  is done
# 782  is done
# 783  is done
# 784  is done
# 785  is done
# 786  is done
# 787  is done
# 788  is done
# 789  is done
# 790  is done
# 791  is done
# 792  is done
# 793  is done
# 794  is done
# 795  is done
# 796  is done
# 797  is done
# 798  is done
# 799  is done
# View is not front
# 800  is done
# 801  is done
# 802  is done
# 803  is done
# 804  is done
# 805  is done
# 806  is done
# 807  is done
# 808  is done
# 809  is done
# 810  is done
# 811  is done
# 812  is done
# 813  is done
# 814  is done
# 815  is done
# 816  is done
# 817  is done
# 818  is done
# 819  is done
# 820  is done
# 821  is done
# 822  is done
# 823  is done
# 824  is done
# 825  is done
# 826  is done
# 827  is done
# 828  is done
# 829  is done
# 830  is done
# 831  is done
# 832  is done
# 833  is done
# 834  is done
# 835  is done
# 836  is done
# 837  is done
# 838  is done
# 839  is done
# 840  is done
# 841  is done
# 842  is done
# 843  is done
# 844  is done
# View is not front
# 845  is done
# 846  is done
# 847  is done
# 848  is done
# 849  is done
# 850  is done
# 851  is done
# 852  is done
# 853  is done
# View is not front
# 854  is done
# 855  is done
# 856  is done
# 857  is done
# 858  is done
# 859  is done
# 860  is done
# 861  is done
# 862  is done
# 863  is done
# 864  is done
# 865  is done
# 866  is done
# 867  is done
# 868  is done
# 869  is done
# 870  is done
# 871  is done
# 872  is done
# 873  is done
# 874  is done
# 875  is done
# 876  is done
# 877  is done
# 878  is done
# View is not front
# 879  is done
# 880  is done
# 881  is done
# 882  is done
# 883  is done
# 884  is done
# 885  is done
# 886  is done
# 887  is done
# 888  is done
# 889  is done
# 890  is done
# 891  is done
# 892  is done
# 893  is done
# 894  is done
# 895  is done
# 896  is done
# 897  is done
# 898  is done
# 899  is done
# 900  is done
# 901  is done
# 902  is done
# 903  is done
# 904  is done
# 905  is done
# 906  is done
# 907  is done
# 908  is done
# View is not front
# 909  is done
# 910  is done
# 911  is done
# 912  is done
# 913  is done
# 914  is done
# 915  is done
# 916  is done
# 917  is done
# 918  is done
# 919  is done
# 920  is done
# 921  is done
# 922  is done
# 923  is done
# 924  is done
# 925  is done
# 926  is done
# 927  is done
# 928  is done
# 929  is done
# 930  File error
# 930  is done
# 931  is done
# 932  is done
# 933  is done
# 934  is done
# 935  is done
# 936  is done
# 937  is done
# 938  is done
# 939  is done
# 940  is done
# 941  is done
# 942  is done
# 943  is done
# 944  is done
# 945  is done
# View is not front
# 946  is done
# 947  is done
# 948  is done
# 949  is done
# 950  is done
# 951  is done
# 952  is done
# 953  is done
# View is not front
# 954  is done
# 955  is done
# 956  is done
# 957  is done
# View is not front
# 958  is done
# 959  is done
# 960  is done
# 961  is done
# 962  is done
# 963  is done
# 964  is done
# 965  is done
# 966  is done
# 967  is done
# 968  is done
# 969  is done
# 970  is done
# 971  is done
# 972  is done
# 973  is done
# 974  is done
# 975  is done
# 976  is done
# 977  is done
# 978  is done
# 979  is done
# 980  is done
# 981  is done
# 982  is done
# 983  is done
# 984  is done
# 985  is done
# 986  is done
# 987  is done
# 988  is done
# 989  is done
# 990  is done
# 991  is done
# 992  is done
# 993  is done
# 994  is done
# 995  is done
# 996  is done
# 997  is done
# 998  is done
# 999  is done
# 1000  is done
# 1001  is done
# 1002  is done
# 1003  is done
# 1004  is done
# 1005  is done
# 1006  is done
# 1007  is done
# 1008  is done
# 1009  is done
# 1010  is done
# 1011  is done
# 1012  is done
# 1013  is done
# 1014  is done
# 1015  is done
# 1016  is done
# 1017  is done
# 1018  is done
# 1019  is done
# 1020  is done
# 1021  is done
# 1022  is done
# 1023  is done
# 1024  is done
# 1025  is done
# 1026  is done
# 1027  is done
# 1028  is done
# 1029  is done
# 1030  is done
# 1031  is done
# 1032  is done
# 1033  is done
# 1034  is done
# 1035  is done
# 1036  is done
# 1037  is done
# 1038  is done
# 1039  is done
# 1040  is done
# 1041  is done
# 1042  is done
# 1043  is done
# 1044  is done
# 1045  is done
# 1046  is done
# 1047  is done
# 1048  is done
# 1049  is done
# 1050  is done
# 1051  is done
# 1052  is done
# 1053  is done
# View is not front
# 1054  is done
# 1055  is done
# 1056  is done
# 1057  is done
# 1058  is done
# 1059  is done
# 1060  is done
# 1061  is done
# 1062  is done
# 1063  is done
# 1064  is done
# 1065  is done
# 1066  is done
# 1067  is done
# 1068  is done
# 1069  is done
# 1070  is done
# 1071  is done
# 1072  is done
# 1073  is done
# 1074  is done
# 1075  is done
# 1076  is done
# 1077  is done
# 1078  is done
# View is not front
# 1079  is done
# 1080  is done
# 1081  is done
# 1082  is done
# 1083  is done
# 1084  is done
# 1085  is done
# View is not front
# 1086  is done
# 1087  is done
# 1088  is done
# 1089  is done
# 1090  is done
# 1091  is done
# 1092  is done
# 1093  is done
# 1094  is done
# 1095  is done
# 1096  is done
# 1097  is done
# 1098  is done
# 1099  is done
# 1100  is done
# 1101  is done
# 1102  is done
# 1103  is done
# 1104  is done
# 1105  is done
# 1106  is done
# 1107  is done
# 1108  is done
# 1109  is done
# 1110  is done
# 1111  is done
# 1112  is done
# 1113  is done
# 1114  is done
# 1115  is done
# 1116  is done
# 1117  is done
# 1118  is done
# 1119  is done
# 1120  is done
# 1121  is done
# 1122  is done
# 1123  is done
# 1124  is done
# 1125  is done
# 1126  is done
# 1127  is done
# 1128  is done
# 1129  is done
# 1130  is done
# 1131  is done
# 1132  is done
# 1133  is done
# 1134  is done
# 1135  is done
# 1136  is done
# 1137  is done
# 1138  is done
# 1139  is done
# 1140  is done
# 1141  is done
# 1142  is done
# 1143  is done
# 1144  is done
# 1145  is done
# 1146  is done
# 1147  is done
# 1148  is done
# 1149  is done
# 1150  is done
# 1151  is done
# 1152  is done
# 1153  is done
# 1154  is done
# 1155  is done
# 1156  is done
# 1157  is done
# 1158  is done
# 1159  is done
# 1160  is done
# 1161  is done
# 1162  is done
# 1163  is done
# 1164  is done
# 1165  is done
# 1166  is done
# 1167  is done
# 1168  is done
# 1169  is done
# 1170  is done
# 1171  is done
# 1172  is done
# 1173  is done
# View is not front
# 1174  is done
# 1175  is done
# 1176  is done
# 1177  is done
# 1178  is done
# 1179  is done
# 1180  is done
# 1181  is done
# 1182  is done
# View is not front
# 1183  is done
# 1184  is done
# 1185  is done
# 1186  is done
# 1187  is done
# 1188  is done
# 1189  is done
# 1190  is done
# 1191  is done
# 1192  is done
# 1193  is done
# 1194  is done
# 1195  is done
# 1196  is done
# 1197  is done
# 1198  is done
# 1199  is done
# View is not front
# 1200  is done
# 1201  is done
# 1202  is done
# 1203  is done
# 1204  is done
# 1205  is done
# 1206  is done
# 1207  is done
# 1208  is done
# 1209  is done
# 1210  is done
# 1211  is done
# 1212  is done
# 1213  is done
# 1214  is done
# 1215  is done
# 1216  is done
# 1217  is done
# 1218  is done
# 1219  is done
# 1220  is done
# 1221  is done
# 1222  is done
# 1223  is done
# 1224  is done
# 1225  is done
# 1226  is done
# 1227  is done
# View is not front
# 1228  is done
# 1229  is done
# 1230  is done
# 1231  is done
# 1232  is done
# 1233  is done
# View is not front
# 1234  is done
# 1235  is done
# 1236  is done
# 1237  is done
# 1238  is done
# 1239  is done
# 1240  is done
# 1241  is done
# 1242  is done
# View is not front
# 1243  is done
# View is not front
# 1244  is done
# 1245  is done
# View is not front
# 1246  is done
# 1247  is done
# 1248  is done
# 1249  is done
# 1250  is done
# 1251  is done
# View is not front
# 1252  is done
# 1253  is done
# 1254  is done
# 1255  is done
# 1256  is done
# 1257  is done
# 1258  is done
# 1259  is done
# 1260  is done
# View is not front
# 1261  is done
# 1262  is done
# 1263  is done
# 1264  is done
# 1265  is done
# 1266  is done
# 1267  is done
# 1268  is done
# 1269  is done
# 1270  is done
# View is not front
# 1271  is done
# 1272  is done
# 1273  is done
# 1274  is done
# 1275  is done
# 1276  is done
# 1277  is done
# 1278  is done
# 1279  is done
# 1280  is done
# 1281  is done
# 1282  is done
# 1283  is done
# 1284  is done
# 1285  is done
# 1286  is done
# 1287  is done
# 1288  is done
# 1289  is done
# 1290  is done
# 1291  is done
# 1292  is done
# 1293  is done
# 1294  is done
# 1295  is done
# 1296  is done
# 1297  is done
# 1298  is done
# View is not front
# 1299  is done
# 1300  is done
# 1301  is done
# View is not front
# 1302  is done
# 1303  is done
# 1304  is done
# View is not front
# 1305  is done
# 1306  is done
# 1307  is done
# 1308  is done
# 1309  is done
# 1310  is done
# 1311  is done
# 1312  is done
# 1313  is done
# 1314  is done
# 1315  is done
# 1316  is done
# 1317  is done
# 1318  is done
# 1319  is done
# 1320  is done
# 1321  is done
# 1322  is done
# 1323  is done
# 1324  is done
# 1325  is done
# 1326  is done
# 1327  is done
# 1328  is done
# 1329  is done
# 1330  is done
# 1331  is done
# 1332  is done
# 1333  is done
# 1334  is done
# 1335  is done
# 1336  is done
# 1337  is done
# 1338  is done
# 1339  is done
# 1340  is done
# 1341  is done
# 1342  is done
# 1343  is done
# 1344  is done
# 1345  is done
# 1346  is done
# 1347  is done
# 1348  is done
# 1349  is done
# 1350  is done
# 1351  is done
# 1352  is done
# 1353  is done
# 1354  is done
# 1355  is done
# 1356  is done
# 1357  is done
# 1358  is done
# 1359  is done
# 1360  is done
# 1361  is done
# View is not front
# 1362  is done
# 1363  is done
# 1364  is done
# 1365  is done
# View is not front
# 1366  is done
# View is not front
# 1367  is done
# 1368  is done
# 1369  is done
# 1370  is done
# 1371  is done
# 1372  is done
# 1373  is done
# 1374  is done
# 1375  is done
# View is not front
# 1376  is done
# 1377  is done
# 1378  is done
# 1379  is done
# 1380  is done
# 1381  is done
# 1382  is done
# 1383  is done
# 1384  is done
# 1385  is done
# 1386  is done
# 1387  is done
# 1388  is done
# 1389  is done
# 1390  is done
# 1391  is done
# 1392  is done
# 1393  is done
# 1394  is done
# 1395  is done
# 1396  is done
# 1397  is done
# 1398  is done
# 1399  is done
# View is not front
# 1400  is done
# 1401  is done
# 1402  is done
# 1403  is done
# 1404  is done
# 1405  is done
# 1406  is done
# 1407  is done
# 1408  is done
# 1409  is done
# 1410  is done
# 1411  is done
# 1412  is done
# 1413  is done
# View is not front
# 1414  is done
# 1415  is done
# 1416  is done
# 1417  is done
# 1418  is done
# 1419  is done
# 1420  is done
# 1421  is done
# 1422  is done
# 1423  is done
# 1424  is done
# 1425  is done
# 1426  is done
# 1427  is done
# 1428  is done
# 1429  is done
# 1430  is done
# 1431  is done
# 1432  is done
# 1433  is done
# 1434  is done
# 1435  is done
# 1436  is done
# 1437  is done
# 1438  is done
# 1439  is done
# 1440  is done
# 1441  is done
# 1442  is done
# 1443  is done
# 1444  is done
# 1445  is done
# 1446  is done
# 1447  is done
# 1448  is done
# 1449  is done
# 1450  is done
# 1451  is done
# 1452  is done
# 1453  is done
# 1454  is done
# 1455  is done
# 1456  is done
# 1457  is done
# 1458  is done
# 1459  is done
# 1460  is done
# 1461  is done
# 1462  is done
# 1463  is done
# 1464  is done
# 1465  is done
# 1466  is done
# 1467  is done
# 1468  is done
# 1469  is done
# 1470  is done
# 1471  is done
# 1472  is done
# 1473  is done
# 1474  is done
# 1475  is done
# 1476  is done
# View is not front
# 1477  is done
# 1478  is done
# 1479  is done
# 1480  is done
# View is not front
# 1481  is done
# 1482  is done
# 1483  is done
# 1484  is done
# 1485  is done
# 1486  is done
# 1487  is done
# 1488  is done
# 1489  is done
# 1490  is done
# 1491  is done
# 1492  is done
# 1493  is done
# 1494  is done
# 1495  is done
# 1496  is done
# 1497  is done
# 1498  is done
# 1499  is done
# 1500  is done
# 1501  is done
# 1502  is done
# 1503  is done
# 1504  is done
# 1505  is done
# 1506  is done
# 1507  is done
# 1508  is done
# 1509  is done
# View is not front
# 1510  is done
# 1511  is done
# 1512  is done
# 1513  is done
# 1514  is done
# 1515  is done
# 1516  is done
# 1517  is done
# 1518  is done
# 1519  is done
# 1520  is done
# 1521  is done
# 1522  is done
# 1523  is done
# 1524  is done
# 1525  is done
# 1526  is done
# 1527  is done
# 1528  is done
# 1529  is done
# 1530  is done
# 1531  is done
# 1532  is done
# 1533  is done
# 1534  is done
# 1535  is done
# 1536  is done
# View is not front
# 1537  is done
# 1538  is done
# 1539  is done
# 1540  is done
# 1541  is done
# 1542  is done
# 1543  is done
# 1544  is done
# 1545  is done
# 1546  is done
# 1547  is done
# 1548  is done
# 1549  is done
# 1550  is done
# 1551  is done
# 1552  is done
# 1553  is done
# 1554  is done
# 1555  is done
# 1556  is done
# 1557  is done
# 1558  is done
# 1559  is done
# 1560  is done
# 1561  is done
# 1562  is done
# 1563  is done
# 1564  is done
# 1565  is done
# 1566  is done
# 1567  is done
# 1568  is done
# 1569  is done
# 1570  is done
# 1571  is done
# 1572  is done
# 1573  is done
# 1574  is done
# 1575  is done
# 1576  is done
# 1577  is done
# 1578  is done
# 1579  is done
# 1580  is done
# 1581  is done
# 1582  is done
# 1583  is done
# View is not front
# 1584  is done
# 1585  is done
# 1586  is done
# 1587  is done
# 1588  is done
# 1589  is done
# 1590  is done
# 1591  is done
# 1592  is done
# 1593  is done
# 1594  is done
# 1595  is done
# 1596  is done
# 1597  is done
# 1598  is done
# 1599  is done
# 1600  is done
# 1601  is done
# 1602  is done
# 1603  is done
# 1604  is done
# 1605  is done
# View is not front
# 1606  is done
# 1607  is done
# 1608  is done
# 1609  is done
# 1610  is done
# 1611  is done
# 1612  is done
# View is not front
# 1613  is done
# 1614  is done
# 1615  is done
# 1616  is done
# 1617  is done
# 1618  is done
# 1619  is done
# 1620  is done
# 1621  is done
# 1622  is done
# 1623  is done
# 1624  is done
# 1625  is done
# 1626  is done
# 1627  is done
# 1628  is done
# 1629  is done
# 1630  is done
# 1631  is done
# 1632  is done
# 1633  is done
# 1634  is done
# 1635  is done
# 1636  is done
# 1637  is done
# 1638  is done
# 1639  is done
# 1640  is done
# 1641  is done
# 1642  is done
# 1643  is done
# 1644  is done
# 1645  is done
# 1646  is done
# 1647  is done
# 1648  is done
# 1649  is done
# 1650  is done
# 1651  is done
# 1652  is done
# 1653  is done
# 1654  is done
# 1655  is done
# 1656  is done
# 1657  is done
# 1658  is done
# 1659  is done
# 1660  is done
# 1661  is done
# 1662  is done
# 1663  is done
# 1664  is done
# 1665  is done
# 1666  is done
# 1667  is done
# 1668  is done
# 1669  is done
# 1670  is done
# 1671  is done
# 1672  is done
# 1673  is done
# 1674  is done
# 1675  is done
# 1676  is done
# 1677  is done
# 1678  is done
# 1679  is done
# 1680  is done
# 1681  is done
# 1682  is done
# 1683  is done
# 1684  is done
# 1685  is done
# 1686  is done
# 1687  is done
# 1688  is done
# 1689  is done
# 1690  is done
# 1691  is done
# 1692  is done
# 1693  is done
# 1694  is done
# 1695  is done
# 1696  is done
# 1697  is done
# 1698  is done
# 1699  is done
# 1700  is done
# 1701  is done
# 1702  is done
# 1703  is done
# 1704  is done
# 1705  is done
# 1706  is done
# 1707  is done
# 1708  is done
# 1709  is done
# 1710  is done
# 1711  is done
# View is not front
# 1712  is done
# 1713  is done
# 1714  is done
# 1715  is done
# 1716  is done
# 1717  is done
# 1718  is done
# 1719  is done
# 1720  is done
# 1721  is done
# 1722  is done
# 1723  is done
# 1724  is done
# 1725  is done
# 1726  is done
# 1727  is done
# View is not front
# 1728  is done
# 1729  is done
# 1730  is done
# 1731  is done
# 1732  is done
# 1733  is done
# 1734  is done
# 1735  is done
# 1736  is done
# 1737  is done
# 1738  is done
# 1739  is done
# 1740  is done
# 1741  is done
# 1742  is done
# 1743  is done
# 1744  is done
# 1745  is done
# 1746  is done
# 1747  is done
# 1748  is done
# 1749  is done
# 1750  is done
# 1751  is done
# 1752  is done
# 1753  is done
# 1754  is done
# 1755  is done
# 1756  is done
# View is not front
# 1757  is done
# 1758  is done
# 1759  is done
# 1760  is done
# 1761  is done
# 1762  is done
# 1763  is done
# 1764  is done
# 1765  is done
# 1766  is done
# 1767  is done
# View is not front
# 1768  is done
# 1769  is done
# 1770  is done
# 1771  is done
# 1772  is done
# View is not front
# 1773  is done
# 1774  is done
# 1775  is done
# 1776  is done
# 1777  is done
# 1778  is done
# 1779  is done
# 1780  is done
# 1781  is done
# 1782  is done
# 1783  is done
# 1784  is done
# 1785  is done
# View is not front
# 1786  is done
# 1787  is done
# 1788  is done
# 1789  is done
# 1790  is done
# 1791  is done
# 1792  is done
# 1793  is done
# 1794  is done
# 1795  is done
# View is not front
# 1796  is done
# 1797  is done
# 1798  is done
# 1799  is done
# 1800  is done
# 1801  is done
# 1802  is done
# 1803  is done
# 1804  is done
# 1805  is done
# 1806  is done
# 1807  is done
# 1808  is done
# 1809  is done
# 1810  is done
# 1811  is done
# 1812  is done
# 1813  is done
# 1814  is done
# 1815  is done
# 1816  is done
# 1817  is done
# 1818  is done
# 1819  is done
# 1820  is done
# 1821  is done
# 1822  is done
# 1823  is done
# 1824  is done
# 1825  is done
# 1826  is done
# 1827  is done
# 1828  is done
# 1829  is done
# 1830  is done
# 1831  is done
# 1832  is done
# 1833  is done
# 1834  is done
# 1835  is done
# 1836  is done
# 1837  is done
# 1838  is done
# 1839  is done
# 1840  is done
# 1841  is done
# 1842  is done
# 1843  is done
# 1844  is done
# 1845  is done
# 1846  is done
# 1847  is done
# 1848  is done
# 1849  is done
# 1850  is done
# 1851  is done
# 1852  is done
# 1853  is done
# 1854  is done
# 1855  is done
# 1856  is done
# 1857  is done
# 1858  is done
# 1859  is done
# 1860  is done
# 1861  is done
# 1862  is done
# 1863  is done
# 1864  is done
# 1865  is done
# 1866  is done
# 1867  is done
# 1868  is done
# 1869  is done
# 1870  is done
# 1871  is done
# 1872  is done
# 1873  is done
# 1874  is done
# 1875  is done
# 1876  is done
# 1877  is done
# 1878  is done
# 1879  is done
# 1880  is done
# 1881  is done
# 1882  is done
# 1883  is done
# 1884  is done
# 1885  is done
# 1886  is done
# 1887  is done
# 1888  is done
# 1889  is done
# 1890  is done
# 1891  is done
# 1892  is done
# 1893  is done
# 1894  is done
# 1895  is done
# 1896  is done
# 1897  is done
# 1898  is done
# 1899  is done
# 1900  is done
# 1901  is done
# 1902  is done
# 1903  is done
# 1904  is done
# 1905  is done
# 1906  is done
# 1907  is done
# 1908  is done
# 1909  is done
# 1910  is done
# 1911  is done
# 1912  is done
# View is not front
# 1913  is done
# 1914  is done
# 1915  is done
# 1916  is done
# 1917  is done
# 1918  is done
# 1919  is done
# 1920  is done
# 1921  is done
# 1922  is done
# 1923  is done
# 1924  is done
# 1925  is done
# View is not front
# 1926  is done
# 1927  is done
# 1928  is done
# 1929  is done
# 1930  is done
# 1931  is done
# 1932  is done
# 1933  is done
# 1934  is done
# 1935  is done
# 1936  is done
# 1937  is done
# 1938  is done
# 1939  is done
# 1940  is done
# 1941  is done
# 1942  is done
# 1943  is done
# 1944  is done
# 1945  is done
# 1946  is done
# 1947  is done
# 1948  is done
# 1949  is done
# 1950  is done
# 1951  is done
# 1952  is done
# 1953  is done
# 1954  is done
# 1955  is done
# 1956  is done
# 1957  is done
# 1958  is done
# 1959  is done
# 1960  is done
# 1961  is done
# 1962  is done
# 1963  is done
# 1964  is done
# 1965  is done
# 1966  is done
# 1967  is done
# 1968  is done
# 1969  is done
# 1970  is done
# 1971  is done
# 1972  is done
# 1973  is done
# 1974  is done
# 1975  is done
# 1976  is done
# 1977  is done
# 1978  is done
# 1979  is done
# 1980  is done
# 1981  is done
# 1982  is done
# 1983  is done
# 1984  is done
# 1985  is done
# 1986  is done
# 1987  is done
# 1988  is done
# 1989  is done
# 1990  is done
# 1991  is done
# 1992  is done
# 1993  is done
# 1994  is done
# 1995  is done
# 1996  is done
# 1997  is done
# 1998  is done
# 1999  is done
# 2000  is done
# 2001  is done
# 2002  is done
# View is not front
# 2003  is done
# 2004  is done
# 2005  is done
# 2006  is done
# 2007  is done
# 2008  is done
# 2009  is done
# 2010  is done
# 2011  is done
# 2012  is done
# 2013  is done
# 2014  is done
# 2015  is done
# 2016  is done
# 2017  is done
# 2018  is done
# 2019  is done
# 2020  is done
# 2021  is done
# 2022  is done
# 2023  is done
# 2024  is done
# 2025  is done
# View is not front
# 2026  is done
# 2027  is done
# 2028  is done
# 2029  is done
# 2030  is done
# 2031  is done
# 2032  is done
# 2033  is done
# 2034  is done
# 2035  is done
# 2036  is done
# 2037  is done
# 2038  is done
# 2039  is done
# 2040  is done
# 2041  is done
# 2042  is done
# 2043  is done
# 2044  is done
# 2045  is done
# 2046  is done
# View is not front
# 2047  is done
# 2048  is done
# 2049  is done
# 2050  is done
# 2051  is done
# 2052  is done
# 2053  is done
# 2054  is done
# 2055  is done
# 2056  is done
# 2057  is done
# 2058  is done
# 2059  is done
# 2060  is done
# 2061  is done
# 2062  is done
# 2063  is done
# 2064  is done
# 2065  is done
# 2066  is done
# 2067  is done
# 2068  is done
# 2069  is done
# 2070  is done
# 2071  is done
# 2072  is done
# 2073  is done
# 2074  is done
# View is not front
# 2075  is done
# 2076  is done
# View is not front
# 2077  is done
# 2078  is done
# 2079  is done
# 2080  is done
# 2081  is done
# 2082  is done
# 2083  is done
# 2084  is done
# 2085  is done
# 2086  is done
# 2087  is done
# 2088  is done
# 2089  is done
# 2090  is done
# 2091  is done
# View is not front
# 2092  is done
# 2093  is done
# 2094  is done
# View is not front
# 2095  is done
# 2096  is done
# 2097  is done
# 2098  is done
# 2099  is done
# 2100  is done
# 2101  is done
# 2102  is done
# 2103  is done
# 2104  is done
# 2105  is done
# 2106  is done
# 2107  is done
# 2108  is done
# 2109  is done
# 2110  is done
# 2111  is done
# 2112  is done
# 2113  is done
# 2114  is done
# 2115  is done
# View is not front
# 2116  is done
# 2117  is done
# 2118  is done
# 2119  is done
# 2120  is done
# 2121  is done
# 2122  is done
# 2123  is done
# 2124  is done
# 2125  is done
# 2126  is done
# 2127  is done
# 2128  is done
# 2129  is done
# View is not front
# 2130  is done
# 2131  is done
# 2132  is done
# View is not front
# 2133  is done
# 2134  is done
# 2135  is done
# 2136  is done
# 2137  is done
# 2138  is done
# View is not front
# 2139  is done
# 2140  is done
# 2141  is done
# 2142  is done
# 2143  is done
# 2144  is done
# 2145  is done
# 2146  is done
# 2147  is done
# 2148  is done
# 2149  is done
# 2150  is done
# 2151  is done
# 2152  is done
# 2153  is done
# 2154  is done
# 2155  is done
# 2156  is done
# 2157  is done
# 2158  is done
# 2159  is done
# 2160  is done
# 2161  is done
# 2162  is done
# 2163  is done
# 2164  is done
# 2165  is done
# 2166  is done
# 2167  is done
# 2168  is done
# View is not front
# 2169  is done
# 2170  is done
# 2171  is done
# 2172  is done
# 2173  is done
# 2174  is done
# 2175  is done
# 2176  is done
# 2177  is done
# 2178  is done
# 2179  is done
# 2180  is done
# 2181  is done
# 2182  is done
# 2183  is done
# 2184  is done
# 2185  is done
# 2186  is done
# 2187  is done
# 2188  is done
# 2189  is done
# 2190  is done
# 2191  is done
# 2192  is done
# 2193  is done
# 2194  is done
# 2195  is done
# 2196  is done
# 2197  is done
# 2198  is done
# 2199  is done
# 2200  is done
# 2201  is done
# 2202  is done
# 2203  is done
# 2204  is done
# 2205  is done
# 2206  is done
# 2207  is done
# 2208  is done
# 2209  is done
# 2210  is done
# 2211  is done
# 2212  is done
# 2213  is done
# 2214  is done
# 2215  is done
# 2216  is done
# 2217  is done
# 2218  is done
# 2219  is done
# 2220  is done
# 2221  is done
# 2222  is done
# 2223  is done
# 2224  is done
# 2225  is done
# 2226  is done
# 2227  is done
# 2228  is done
# 2229  is done
# 2230  is done
# 2231  is done
# 2232  is done
# 2233  is done
# 2234  is done
# 2235  is done
# 2236  is done
# 2237  is done
# 2238  is done
# 2239  is done
# 2240  is done
# 2241  is done
# 2242  is done
# 2243  is done
# 2244  is done
# 2245  is done
# 2246  is done
# 2247  is done
# 2248  is done
# 2249  is done
# 2250  is done
# 2251  is done
# 2252  is done
# 2253  is done
# 2254  is done
# 2255  is done
# 2256  is done
# 2257  is done
# 2258  is done
# 2259  is done
# 2260  is done
# 2261  is done
# 2262  is done
# 2263  is done
# 2264  is done
# 2265  is done
# 2266  is done
# 2267  is done
# 2268  is done
# 2269  is done
# 2270  is done
# 2271  is done
# 2272  is done
# 2273  is done
# 2274  is done
# 2275  is done
# 2276  is done
# 2277  is done
# 2278  is done
# 2279  is done
# 2280  is done
# 2281  is done
# 2282  is done
# 2283  is done
# 2284  is done
# 2285  is done
# 2286  is done
# 2287  is done
# 2288  is done
# 2289  is done
# 2290  is done
# 2291  is done
# 2292  is done
# 2293  is done
# 2294  is done
# 2295  is done
# 2296  is done
# 2297  is done
# 2298  is done
# 2299  is done
# 2300  is done
# 2301  is done
# 2302  is done
# 2303  is done
# 2304  is done
# 2305  is done
# 2306  is done
# 2307  is done
# 2308  is done
# 2309  is done
# 2310  is done
# 2311  is done
# 2312  is done
# 2313  is done
# 2314  is done
# 2315  is done
# 2316  is done
# 2317  is done
# 2318  is done
# 2319  is done
# 2320  is done
# 2321  is done
# 2322  is done
# 2323  is done
# 2324  is done
# 2325  is done
# 2326  is done
# 2327  is done
# 2328  is done
# 2329  is done
# 2330  is done
# 2331  is done
# 2332  is done
# 2333  is done
# 2334  is done
# 2335  is done
# 2336  is done
# 2337  is done
# 2338  is done
# 2339  is done
# 2340  is done
# 2341  is done
# 2342  is done
# 2343  is done
# 2344  is done
# 2345  is done
# 2346  is done
# 2347  is done
# 2348  is done
# 2349  is done
# 2350  is done
# 2351  is done
# 2352  is done
# 2353  is done
# 2354  is done
# 2355  is done
# 2356  is done
# 2357  is done
# 2358  is done
# 2359  is done
# 2360  is done
# 2361  is done
# 2362  is done
# 2363  is done
# 2364  is done
# 2365  is done
# 2366  is done
# 2367  is done
# 2368  is done
# 2369  is done
# 2370  is done
# 2371  is done
# 2372  is done
# 2373  is done
# 2374  is done
# 2375  is done
# View is not front
# 2376  is done
# 2377  is done
# 2378  is done
# 2379  is done
# 2380  is done
# 2381  is done
# 2382  is done
# 2383  is done
# 2384  is done
# 2385  is done
# 2386  is done
# 2387  is done
# 2388  is done
# 2389  is done
# 2390  is done
# 2391  is done
# 2392  is done
# 2393  is done
# 2394  is done
# 2395  is done
# 2396  is done
# 2397  is done
# 2398  is done
# 2399  is done
# 2400  is done
# 2401  is done
# 2402  is done
# View is not front
# 2403  is done
# 2404  is done
# 2405  is done
# View is not front
# 2406  is done
# 2407  is done
# 2408  is done
# 2409  is done
# 2410  is done
# 2411  is done
# View is not front
# 2412  is done
# 2413  is done
# 2414  is done
# 2415  is done
# 2416  is done
# 2417  is done
# 2418  is done
# 2419  is done
# 2420  is done
# View is not front
# 2421  is done
# 2422  is done
# 2423  is done
# 2424  is done
# 2425  is done
# View is not front
# 2426  is done
# 2427  is done
# 2428  is done
# 2429  is done
# 2430  is done
# 2431  is done
# 2432  is done
# 2433  is done
# 2434  is done
# 2435  is done
# 2436  is done
# 2437  is done
# 2438  is done
# 2439  is done
# 2440  is done
# 2441  is done
# 2442  is done
# 2443  is done
# 2444  is done
# 2445  is done
# 2446  is done
# 2447  is done
# View is not front
# 2448  is done
# 2449  is done
# 2450  is done
# 2451  is done
# 2452  is done
# 2453  is done
# 2454  is done
# 2455  is done
# 2456  is done
# 2457  is done
# 2458  is done
# 2459  is done
# 2460  is done
# 2461  is done
# 2462  is done
# 2463  is done
# 2464  is done
# 2465  is done
# 2466  is done
# 2467  is done
# 2468  is done
# 2469  is done
# 2470  is done
# 2471  is done
# 2472  is done
# 2473  is done
# 2474  is done
# 2475  is done
# 2476  is done
# 2477  is done
# View is not front
# 2478  is done
# 2479  is done
# 2480  is done
# 2481  is done
# 2482  is done
# 2483  is done
# 2484  is done
# 2485  is done
# 2486  is done
# 2487  is done
# View is not front
# 2488  is done
# 2489  is done
# 2490  is done
# 2491  is done
# 2492  is done
# 2493  is done
# 2494  is done
# 2495  is done
# 2496  is done
# View is not front
# 2497  is done
# 2498  is done
# 2499  is done
# 2500  is done
# 2501  is done
# 2502  is done
# 2503  is done
# 2504  is done
# 2505  is done
# 2506  is done
# View is not front
# 2507  is done
# 2508  is done
# 2509  is done
# 2510  is done
# 2511  is done
# 2512  is done
# 2513  is done
# 2514  is done
# 2515  is done
# 2516  is done
# 2517  is done
# 2518  is done
# 2519  is done
# 2520  is done
# 2521  is done
# 2522  is done
# 2523  is done
# 2524  is done
# 2525  is done
# 2526  is done
# 2527  is done
# 2528  is done
# 2529  is done
# 2530  is done
# 2531  is done
# 2532  is done
# 2533  is done
# 2534  is done
# 2535  is done
# View is not front
# 2536  is done
# 2537  is done
# 2538  is done
# 2539  is done
# 2540  is done
# 2541  is done
# 2542  is done
# 2543  is done
# 2544  is done
# 2545  is done
# 2546  is done
# 2547  is done
# 2548  is done
# 2549  is done
# 2550  is done
# 2551  is done
# 2552  is done
# 2553  is done
# 2554  is done
# 2555  is done
# 2556  is done
# 2557  is done
# 2558  is done
# 2559  is done
# 2560  is done
# 2561  is done
# 2562  is done
# 2563  is done
# 2564  is done
# 2565  is done
# 2566  is done
# 2567  is done
# 2568  is done
# 2569  is done
# 2570  is done
# 2571  is done
# 2572  is done
# 2573  is done
# 2574  is done
# 2575  is done
# 2576  is done
# 2577  is done
# 2578  is done
# 2579  is done
# 2580  is done
# View is not front
# 2581  is done
# 2582  is done
# 2583  is done
# 2584  is done
# 2585  is done
# 2586  is done
# 2587  is done
# 2588  is done
# 2589  is done
# 2590  is done
# 2591  is done
# 2592  is done
# 2593  is done
# 2594  is done
# 2595  is done
# 2596  is done
# 2597  is done
# 2598  is done
# 2599  is done
# 2600  is done
# 2601  is done
# 2602  is done
# 2603  is done
# 2604  is done
# 2605  is done
# 2606  is done
# 2607  is done
# 2608  is done
# 2609  is done
# 2610  is done
# 2611  is done
# 2612  is done
# 2613  is done
# 2614  is done
# 2615  is done
# 2616  is done
# 2617  is done
# 2618  is done
# 2619  is done
# 2620  is done
# 2621  is done
# 2622  is done
# 2623  is done
# 2624  is done
# 2625  is done
# 2626  is done
# 2627  is done
# 2628  is done
# 2629  is done
# 2630  is done
# 2631  is done
# 2632  is done
# 2633  is done
# 2634  is done
# 2635  is done
# 2636  is done
# 2637  is done
# 2638  is done
# 2639  is done
# 2640  is done
# 2641  is done
# 2642  is done
# 2643  is done
# 2644  is done
# 2645  is done
# 2646  is done
# 2647  is done
# 2648  is done
# 2649  is done
# 2650  is done
# 2651  is done
# 2652  is done
# 2653  is done
# 2654  is done
# 2655  is done
# 2656  is done
# 2657  is done
# 2658  is done
# 2659  is done
# 2660  is done
# 2661  is done
# 2662  is done
# 2663  is done
# 2664  is done
# 2665  is done
# 2666  is done
# 2667  is done
# 2668  is done
# 2669  is done
# 2670  is done
# 2671  is done
# 2672  is done
# 2673  is done
# 2674  is done
# 2675  is done
# 2676  is done
# 2677  is done
# 2678  is done
# 2679  is done
# 2680  is done
# 2681  is done
# 2682  is done
# 2683  is done
# 2684  is done
# 2685  is done
# 2686  is done
# 2687  is done
# 2688  is done
# 2689  is done
# 2690  is done
# 2691  is done
# 2692  is done
# 2693  is done
# 2694  is done
# 2695  is done
# 2696  is done
# 2697  is done
# 2698  is done
# 2699  is done
# 2700  is done
# 2701  is done
# 2702  is done
# 2703  is done
# 2704  is done
# 2705  is done
# 2706  is done
# 2707  is done
# 2708  is done
# 2709  is done
# 2710  is done
# 2711  is done
# 2712  is done
# 2713  is done
# 2714  is done
# 2715  is done
# 2716  is done
# 2717  is done
# 2718  is done
# 2719  is done
# 2720  is done
# 2721  is done
# 2722  is done
# 2723  is done
# 2724  is done
# 2725  is done
# 2726  is done
# 2727  is done
# 2728  is done
# 2729  is done
# 2730  is done
# 2731  is done
# 2732  is done
# 2733  is done
# 2734  is done
# 2735  is done
# 2736  is done
# 2737  is done
# 2738  is done
# 2739  is done
# 2740  is done
# 2741  is done
# 2742  is done
# 2743  is done
# 2744  is done
# 2745  is done
# 2746  is done
# 2747  is done
# 2748  is done
# 2749  is done
# 2750  is done
# 2751  is done
# 2752  is done
# 2753  is done
# 2754  is done
# 2755  is done
# 2756  is done
# 2757  is done
# 2758  is done
# 2759  is done
# 2760  is done
# 2761  is done
# 2762  is done
# 2763  is done
# 2764  is done
# 2765  is done
# 2766  is done
# 2767  is done
# 2768  is done
# 2769  is done
# 2770  is done
# 2771  is done
# 2772  is done
# 2773  is done
# 2774  is done
# 2775  is done
# 2776  is done
# 2777  is done
# 2778  is done
# 2779  is done
# 2780  is done
# 2781  is done
# 2782  is done
# 2783  is done
# 2784  is done
# 2785  is done
# 2786  is done
# 2787  is done
# 2788  is done
# 2789  is done
# 2790  is done
# 2791  is done
# 2792  is done
# 2793  is done
# 2794  is done
# 2795  is done
# 2796  is done
# 2797  is done
# 2798  is done
# 2799  is done
# 2800  is done
# 2801  is done
# 2802  is done
# 2803  is done
# 2804  is done
# 2805  is done
# 2806  is done
# 2807  is done
# 2808  is done
# 2809  is done
# 2810  is done
# 2811  is done
# 2812  is done
# 2813  is done
# 2814  is done
# 2815  is done
# 2816  is done
# 2817  is done
# 2818  is done
# 2819  is done
# 2820  is done
# 2821  is done
# 2822  is done
# 2823  is done
# 2824  is done
# 2825  is done
# 2826  is done
# 2827  is done
# 2828  is done
# 2829  is done
# 2830  is done
# 2831  is done
# 2832  is done
# 2833  File error
# 2833  is done
# 2834  is done
# 2835  is done
# 2836  is done
# 2837  is done
# 2838  is done
# 2839  is done
# 2840  is done
# 2841  is done
# 2842  is done
# 2843  is done
# 2844  is done
# 2845  is done
# 2846  is done
# 2847  is done
# 2848  is done
# 2849  is done
# View is not front
# 2850  is done
# 2851  is done
# 2852  is done
# 2853  is done
# 2854  is done
# 2855  is done
# 2856  is done
# 2857  is done
# 2858  is done
# 2859  is done
# 2860  is done
# 2861  is done
# 2862  is done
# 2863  is done
# 2864  is done
# 2865  is done
# 2866  is done
# 2867  is done
# 2868  is done
# 2869  is done
# 2870  is done
# 2871  is done
# 2872  is done
# 2873  is done
# 2874  is done
# 2875  File error
# 2875  is done
# 2876  is done
# 2877  is done
# 2878  is done
# 2879  is done
# 2880  is done
# 2881  is done
# 2882  is done
# 2883  is done
# 2884  is done
# 2885  is done
# 2886  is done
# 2887  is done
# 2888  is done
# 2889  is done
# 2890  is done
# 2891  is done
# 2892  is done
# 2893  is done
# 2894  is done
# 2895  is done
# 2896  is done
# 2897  is done
# 2898  is done
# 2899  is done
# 2900  is done
# 2901  is done
# 2902  is done
# 2903  is done
# 2904  is done
# View is not front
# 2905  is done
# 2906  is done
# 2907  is done
# 2908  is done
# 2909  is done
# 2910  is done
# 2911  is done
# 2912  is done
# 2913  is done
# View is not front
# 2914  is done
# 2915  is done
# 2916  is done
# 2917  is done
# 2918  is done
# 2919  is done
# 2920  is done
# 2921  is done
# 2922  is done
# 2923  is done
# 2924  is done
# 2925  is done
# 2926  is done
# 2927  is done
# 2928  is done
# 2929  is done
# 2930  is done
# 2931  is done
# 2932  is done
# 2933  is done
# 2934  is done
# 2935  is done
# 2936  is done
# 2937  is done
# 2938  is done
# 2939  is done
# 2940  is done
# 2941  is done
# 2942  is done
# 2943  is done
# 2944  is done
# 2945  is done
# View is not front
# 2946  is done
# 2947  is done
# 2948  is done
# 2949  is done
# 2950  is done
# 2951  is done
# 2952  is done
# 2953  is done
# 2954  is done
# 2955  is done
# 2956  is done
# 2957  is done
# 2958  is done
# 2959  is done
# 2960  is done
# 2961  is done
# 2962  is done
# 2963  is done
# 2964  is done
# 2965  is done
# 2966  is done
# 2967  is done
# 2968  is done
# 2969  is done
# 2970  is done
# 2971  is done
# 2972  is done
# 2973  is done
# 2974  is done
# 2975  is done
# 2976  is done
# 2977  is done
# 2978  is done
# 2979  is done
# 2980  is done
# 2981  is done
# 2982  is done
# 2983  is done
# 2984  is done
# 2985  is done
# 2986  is done
# 2987  is done
# 2988  is done
# 2989  is done
# 2990  is done
# 2991  is done
# 2992  is done
# 2993  is done
# View is not front
# 2994  is done
# 2995  is done
# 2996  is done
# 2997  is done
# 2998  is done
# 2999  is done
# 3000  is done
# 3001  is done
# 3002  is done
# 3003  is done
# 3004  is done
# 3005  is done
# 3006  is done
# 3007  is done
# 3008  is done
# 3009  is done
# 3010  is done
# 3011  is done
# 3012  is done
# 3013  is done
# 3014  is done
# 3015  is done
# 3016  is done
# 3017  is done
# 3018  is done
# 3019  is done
# 3020  is done
# 3021  is done
# 3022  is done
# 3023  is done
# 3024  is done
# 3025  is done
# 3026  is done
# 3027  is done
# 3028  is done
# 3029  is done
# 3030  is done
# 3031  is done
# 3032  is done
# 3033  is done
# 3034  is done
# 3035  is done
# 3036  is done
# 3037  is done
# 3038  is done
# 3039  is done
# 3040  is done
# 3041  is done
# View is not front
# 3042  is done
# 3043  is done
# 3044  is done
# 3045  is done
# 3046  is done
# 3047  is done
# 3048  is done
# 3049  is done
# 3050  is done
# 3051  is done
# 3052  is done
# 3053  is done
# 3054  is done
# 3055  is done
# 3056  is done
# 3057  is done
# 3058  is done
# 3059  is done
# 3060  is done
# View is not front
# 3061  is done
# 3062  is done
# 3063  is done
# 3064  is done
# 3065  is done
# 3066  is done
# 3067  is done
# 3068  is done
# 3069  is done
# 3070  is done
# 3071  is done
# 3072  is done
# 3073  is done
# 3074  is done
# 3075  is done
# 3076  is done
# 3077  is done
# 3078  is done
# 3079  is done
# 3080  is done
# 3081  is done
# 3082  is done
# 3083  is done
# 3084  is done
# 3085  is done
# 3086  is done
# View is not front
# 3087  is done
# 3088  is done
# 3089  is done
# 3090  is done
# 3091  is done
# 3092  is done
# 3093  is done
# 3094  is done
# 3095  is done
# 3096  is done
# 3097  is done
# 3098  is done
# 3099  is done
# 3100  is done
# 3101  is done
# 3102  is done
# 3103  is done
# 3104  is done
# 3105  is done
# 3106  is done
# 3107  is done
# 3108  is done
# 3109  is done
# 3110  is done
# 3111  is done
# 3112  is done
# 3113  is done
# 3114  is done
# 3115  is done
# 3116  is done
# View is not front
# 3117  is done
# 3118  is done
# 3119  is done
# 3120  is done
# 3121  is done
# 3122  is done
# 3123  is done
# 3124  is done
# 3125  is done
# 3126  is done
# 3127  is done
# 3128  is done
# 3129  is done
# 3130  is done
# 3131  is done
# 3132  is done
# 3133  is done
# 3134  is done
# 3135  is done
# 3136  is done
# 3137  is done
# 3138  is done
# 3139  is done
# 3140  is done
# 3141  is done
# 3142  is done
# 3143  is done
# 3144  is done
# 3145  is done
# 3146  is done
# 3147  is done
# 3148  is done
# 3149  is done
# 3150  is done
# 3151  is done
# 3152  is done
# 3153  is done
# 3154  is done
# 3155  is done
# 3156  is done
# 3157  is done
# 3158  is done
# 3159  is done
# 3160  is done
# 3161  is done
# 3162  is done
# 3163  is done
# 3164  is done
# 3165  is done
# 3166  is done
# 3167  is done
# 3168  is done
# 3169  is done
# 3170  is done
# 3171  is done
# 3172  is done
# View is not front
# 3173  is done
# 3174  is done
# 3175  is done
# 3176  is done
# 3177  is done
# 3178  is done
# 3179  is done
# 3180  is done
# 3181  is done
# 3182  is done
# 3183  is done
# 3184  is done
# 3185  is done
# 3186  is done
# 3187  is done
# 3188  is done
# 3189  is done
# 3190  is done
# 3191  is done
# 3192  is done
# 3193  is done
# 3194  is done
# 3195  is done
# 3196  is done
# 3197  is done
# 3198  is done
# 3199  is done
# 3200  is done
# 3201  is done
# 3202  is done
# 3203  is done
# 3204  is done
# 3205  is done
# 3206  is done
# 3207  is done
# 3208  is done
# 3209  is done
# 3210  is done
# 3211  is done
# 3212  is done
# 3213  is done
# 3214  is done
# 3215  is done
# 3216  is done
# 3217  is done
# 3218  is done
# 3219  is done
# 3220  is done
# 3221  is done
# 3222  is done
# 3223  is done
# 3224  is done
# 3225  is done
# 3226  is done
# 3227  is done
# 3228  is done
# 3229  is done
# 3230  is done
# 3231  is done
# 3232  is done
# 3233  is done
# 3234  is done
# 3235  is done
# 3236  is done
# 3237  is done
# 3238  is done
# 3239  is done
# 3240  is done
# 3241  is done
# 3242  is done
# 3243  is done
# 3244  is done
# 3245  is done
# 3246  is done
# 3247  is done
# 3248  is done
# 3249  is done
# 3250  is done
# 3251  is done
# 3252  is done
# View is not front
# 3253  is done
# 3254  is done
# 3255  is done
# 3256  is done
# 3257  is done
# 3258  is done
# 3259  is done
# 3260  is done
# 3261  is done
# 3262  is done
# 3263  is done
# 3264  is done
# 3265  is done
# 3266  is done
# 3267  is done
# 3268  is done
# 3269  is done
# 3270  is done
# 3271  is done
# 3272  is done
# 3273  is done
# 3274  is done
# 3275  is done
# 3276  is done
# 3277  is done
# 3278  is done
# 3279  is done
# 3280  is done
# 3281  is done
# 3282  is done
# 3283  is done
# 3284  is done
# 3285  is done
# 3286  is done
# 3287  is done
# 3288  is done
# 3289  is done
# 3290  is done
# 3291  is done
# 3292  is done
# 3293  is done
# 3294  is done
# 3295  is done
# 3296  is done
# 3297  is done
# 3298  is done
# 3299  is done
# 3300  is done
# 3301  is done
# 3302  is done
# 3303  is done
# 3304  is done
# 3305  is done
# 3306  is done
# 3307  is done
# 3308  is done
# 3309  is done
# 3310  is done
# 3311  is done
# 3312  is done
# 3313  is done
# 3314  is done
# 3315  is done
# 3316  is done
# 3317  is done
# View is not front
# 3318  is done
# 3319  is done
# 3320  is done
# 3321  is done
# 3322  is done
# 3323  is done
# 3324  is done
# 3325  is done
# 3326  is done
# View is not front
# 3327  is done
# 3328  is done
# 3329  is done
# 3330  is done
# 3331  is done
# 3332  is done
# 3333  is done
# 3334  is done
# 3335  is done
# 3336  is done
# 3337  is done
# 3338  is done
# 3339  is done
# 3340  is done
# 3341  is done
# 3342  is done
# 3343  is done
# 3344  is done
# 3345  is done
# 3346  is done
# 3347  is done
# 3348  is done
# 3349  is done
# 3350  is done
# 3351  is done
# 3352  is done
# 3353  is done
# 3354  is done
# 3355  is done
# 3356  is done
# 3357  is done
# 3358  is done
# 3359  is done
# 3360  is done
# 3361  is done
# 3362  is done
# 3363  is done
# 3364  is done
# 3365  is done
# 3366  is done
# 3367  is done
# 3368  is done
# 3369  is done
# 3370  is done
# 3371  is done
# 3372  is done
# 3373  is done
# 3374  is done
# 3375  is done
# 3376  is done
# 3377  is done
# 3378  is done
# 3379  is done
# 3380  is done
# 3381  is done
# 3382  is done
# 3383  is done
# 3384  is done
# 3385  is done
# 3386  is done
# 3387  is done
# 3388  is done
# 3389  is done
# 3390  is done
# 3391  is done
# 3392  is done
# 3393  is done
# 3394  is done
# 3395  is done
# 3396  is done
# 3397  is done
# 3398  is done
# 3399  is done
# 3400  is done
# 3401  is done
# 3402  is done
# 3403  is done
# View is not front
# 3404  is done
# 3405  is done
# 3406  is done
# 3407  is done
# 3408  is done
# 3409  is done
# 3410  is done
# 3411  is done
# 3412  is done
# 3413  is done
# 3414  is done
# 3415  is done
# 3416  is done
# 3417  is done
# 3418  is done
# 3419  is done
# 3420  is done
# 3421  is done
# 3422  is done
# 3423  is done
# 3424  is done
# 3425  is done
# 3426  is done
# 3427  is done
# 3428  is done
# 3429  is done
# 3430  is done
# 3431  is done
# 3432  is done
# 3433  is done
# 3434  is done
# 3435  is done
# 3436  is done
# 3437  is done
# 3438  is done
# 3439  is done
# 3440  is done
# 3441  is done
# 3442  is done
# 3443  is done
# 3444  is done
# 3445  is done
# 3446  is done
# View is not front
# 3447  is done
# 3448  is done
# 3449  is done
# 3450  is done
# 3451  is done
# 3452  is done
# 3453  is done
# 3454  is done
# 3455  is done
# 3456  is done
# 3457  is done
# 3458  is done
# 3459  is done
# 3460  is done
# 3461  is done
# 3462  is done
# 3463  is done
# 3464  is done
# 3465  is done
# 3466  is done
# 3467  is done
# 3468  is done
# 3469  is done
# 3470  is done
# 3471  is done
# 3472  is done
# 3473  is done
# 3474  is done
# 3475  is done
# 3476  is done
# 3477  is done
# 3478  is done
# 3479  is done
# 3480  is done
# 3481  is done
# 3482  is done
# 3483  is done
# 3484  is done
# 3485  is done
# 3486  is done
# 3487  is done
# 3488  is done
# 3489  is done
# 3490  is done
# 3491  is done
# 3492  is done
# 3493  is done
# 3494  is done
# 3495  is done
# 3496  is done
# 3497  is done
# 3498  is done
# 3499  is done
# 3500  is done
# 3501  is done
# 3502  is done
# 3503  is done
# 3504  is done
# 3505  is done
# 3506  is done
# 3507  is done
# View is not front
# 3508  is done
# 3509  is done
# 3510  is done
# 3511  is done
# 3512  is done
# 3513  is done
# 3514  is done
# 3515  is done
# 3516  is done
# 3517  is done
# 3518  is done
# 3519  is done
# 3520  is done
# 3521  is done
# 3522  is done
# 3523  is done
# View is not front
# 3524  is done
# 3525  is done
# 3526  is done
# 3527  is done
# View is not front
# 3528  is done
# 3529  is done
# 3530  is done
# 3531  is done
# 3532  is done
# 3533  is done
# 3534  is done
# 3535  is done
# 3536  is done
# 3537  is done
# 3538  is done
# 3539  is done
# 3540  is done
# 3541  is done
# 3542  is done
# 3543  is done
# 3544  is done
# 3545  is done
# 3546  is done
# 3547  is done
# 3548  is done
# 3549  is done
# 3550  is done
# 3551  is done
# 3552  is done
# 3553  is done
# 3554  is done
# 3555  is done
# 3556  is done
# 3557  is done
# 3558  is done
# 3559  is done
# 3560  is done
# 3561  is done
# 3562  is done
# View is not front
# 3563  is done
# 3564  is done
# 3565  is done
# 3566  is done
# 3567  is done
# 3568  is done
# 3569  is done
# 3570  is done
# 3571  is done
# 3572  is done
# 3573  is done
# 3574  is done
# 3575  is done
# 3576  is done
# 3577  is done
# 3578  is done
# 3579  is done
# 3580  is done
# 3581  is done
# 3582  is done
# 3583  is done
# 3584  is done
# 3585  is done
# 3586  is done
# 3587  is done
# 3588  is done
# 3589  is done
# 3590  is done
# 3591  is done
# 3592  is done
# 3593  is done
# 3594  is done
# 3595  is done
# 3596  is done
# 3597  is done
# 3598  is done
# 3599  is done
# 3600  is done
# 3601  is done
# 3602  is done
# 3603  is done
# 3604  is done
# 3605  is done
# 3606  is done
# 3607  is done
# 3608  is done
# 3609  is done
# 3610  is done
# 3611  is done
# 3612  File error
# 3612  is done
# 3613  is done
# 3614  is done
# 3615  is done
# 3616  is done
# 3617  is done
# 3618  is done
# 3619  is done
# 3620  is done
# 3621  is done
# 3622  is done
# 3623  is done
# 3624  is done
# 3625  is done
# 3626  is done
# 3627  is done
# 3628  is done
# 3629  is done
# 3630  is done
# 3631  is done
# 3632  is done
# 3633  is done
# 3634  is done
# 3635  is done
# 3636  is done
# 3637  is done
# 3638  is done
# 3639  is done
# 3640  is done
# 3641  is done
# 3642  is done
# 3643  is done
# 3644  is done
# 3645  is done
# 3646  is done
# 3647  is done
# 3648  is done
# 3649  is done
# 3650  is done
# 3651  is done
# 3652  is done
# 3653  is done
# 3654  is done
# 3655  is done
# 3656  is done
# 3657  is done
# 3658  is done
# 3659  is done
# 3660  is done
# 3661  is done
# 3662  is done
# 3663  is done
# 3664  is done
# 3665  is done
# View is not front
# 3666  is done
# 3667  is done
# 3668  is done
# 3669  is done
# 3670  is done
# 3671  is done
# 3672  is done
# 3673  is done
# 3674  is done
# 3675  is done
# 3676  is done
# 3677  is done
# 3678  is done
# 3679  is done
# 3680  is done
# 3681  is done
# 3682  is done
# 3683  is done
# 3684  is done
# 3685  is done
# 3686  is done
# 3687  is done
# 3688  is done
# 3689  is done
# 3690  is done
# 3691  is done
# 3692  is done
# 3693  is done
# 3694  is done
# 3695  is done
# 3696  is done
# 3697  is done
# 3698  is done
# 3699  is done
# 3700  is done
# 3701  is done
# 3702  is done
# 3703  is done
# 3704  is done
# 3705  is done
# 3706  is done
# 3707  is done
# 3708  is done
# 3709  is done
# 3710  is done
# 3711  is done
# 3712  is done
# 3713  is done
# 3714  is done
# 3715  is done
# 3716  is done
# 3717  is done
# 3718  is done
# 3719  is done
# 3720  is done
# 3721  is done
# 3722  is done
# 3723  is done
# 3724  is done
# 3725  is done
# 3726  is done
# 3727  is done
# 3728  is done
# 3729  is done
# 3730  is done
# 3731  is done
# 3732  is done
# 3733  is done
# 3734  is done
# 3735  is done
# 3736  is done
# 3737  is done
# 3738  is done
# 3739  is done
# 3740  is done
# 3741  is done
# 3742  is done
# 3743  is done
# 3744  is done
# 3745  is done
# 3746  is done
# 3747  is done
# 3748  is done
# 3749  is done
# 3750  is done
# 3751  is done
# 3752  is done
# 3753  is done
# 3754  is done
# 3755  is done
# 3756  is done
# 3757  is done
# 3758  is done
# 3759  is done
# 3760  is done
# 3761  is done
# 3762  is done
# 3763  is done
# 3764  is done
# 3765  is done
# 3766  is done
# 3767  is done
# 3768  is done
# 3769  is done
# 3770  is done
# 3771  is done
# 3772  is done
# 3773  is done
# 3774  is done
# 3775  is done
# 3776  is done
# 3777  is done
# 3778  is done
# 3779  is done
# 3780  is done
# 3781  is done
# 3782  is done
# 3783  is done
# 3784  is done
# 3785  is done
# 3786  is done
# 3787  is done
# 3788  is done
# 3789  is done
# 3790  is done
# 3791  is done
# 3792  is done
# 3793  is done
# 3794  is done
# 3795  is done
# 3796  is done
# 3797  is done
# 3798  is done
# 3799  is done
# 3800  is done
# 3801  is done
# 3802  is done
# 3803  is done
# 3804  is done
# 3805  is done
# 3806  is done
# 3807  is done
# 3808  is done
# 3809  is done
# 3810  is done
# 3811  is done
# 3812  is done
# View is not front
# 3813  is done
# 3814  is done
# 3815  is done
# 3816  is done
# 3817  is done
# View is not front
# 3818  is done
# 3819  is done
# 3820  is done
# 3821  is done
# 3822  is done
# 3823  is done
# 3824  is done
# 3825  is done
# 3826  is done
# 3827  is done
# 3828  is done
# 3829  is done
# 3830  is done
# View is not front
# 3831  is done
# 3832  is done
# 3833  is done
# View is not front
# 3834  is done
# 3835  is done
# 3836  is done
# 3837  is done
# 3838  is done
# 3839  is done
# 3840  is done
# 3841  is done
# 3842  is done
# 3843  is done
# 3844  is done
# 3845  is done
# 3846  is done
# 3847  is done
# 3848  is done
# 3849  is done
# 3850  is done
# 3851  is done
# 3852  is done
# 3853  is done
# 3854  is done
# 3855  is done
# 3856  is done
# 3857  is done
# 3858  is done
# 3859  is done
# 3860  is done
# View is not front
# 3861  is done
# 3862  is done
# 3863  is done
# 3864  is done
# 3865  is done
# 3866  is done
# 3867  is done
# 3868  is done
# 3869  is done
# 3870  is done
# 3871  is done
# View is not front
# 3872  is done
# 3873  is done
# 3874  is done
# 3875  is done
# 3876  is done
# 3877  is done
# 3878  is done
# 3879  is done
# 3880  is done
# 3881  is done
# View is not front
# 3882  is done
# 3883  is done
# 3884  is done
# 3885  is done
# 3886  is done
# 3887  is done
# 3888  is done
# 3889  is done
# 3890  is done
# 3891  is done
# 3892  is done
# 3893  is done
# 3894  is done
# 3895  is done
# 3896  is done
# 3897  is done
# 3898  is done
# 3899  is done
# 3900  is done
# View is not front
# 3901  is done
# 3902  is done
# 3903  is done
# 3904  is done
# 3905  is done
# 3906  is done
# View is not front
# 3907  is done
# 3908  is done
# 3909  is done
# 3910  is done
# 3911  is done
# 3912  is done
# 3913  is done
# 3914  is done
# 3915  is done
# 3916  is done
# 3917  is done
# 3918  is done
# 3919  is done
# 3920  is done
# 3921  is done
# 3922  is done
# 3923  is done
# 3924  is done
# 3925  is done
# 3926  is done
# 3927  is done
# 3928  is done
# 3929  is done
# 3930  is done
# 3931  is done
# 3932  is done
# 3933  is done
# 3934  is done
# 3935  is done
# 3936  is done
# 3937  is done
# 3938  is done
# 3939  is done
# 3940  is done
# 3941  is done
# 3942  is done
# 3943  is done
# 3944  is done
# 3945  is done
# 3946  is done
# 3947  is done
# 3948  is done
# 3949  is done
# 3950  is done
# 3951  is done
# 3952  is done
# 3953  is done
# 3954  is done
# 3955  is done
# 3956  is done
# 3957  is done
# 3958  is done
# 3959  is done
# 3960  is done
# 3961  is done
# 3962  is done
# 3963  is done
# 3964  is done
# 3965  is done
# 3966  is done
# 3967  is done
# 3968  is done
# 3969  is done
# 3970  is done
# 3971  is done
# 3972  is done
# 3973  is done
# 3974  is done
# 3975  is done
# 3976  is done
# 3977  is done
# 3978  is done
# 3979  is done
# 3980  is done
# 3981  is done
# 3982  is done
# 3983  is done
# View is not front
# 3984  is done
# 3985  is done
# 3986  is done
# 3987  is done
# 3988  is done
# 3989  is done
# 3990  is done
# 3991  is done
# 3992  is done
# 3993  is done
# 3994  is done
# 3995  is done
# View is not front
# 3996  is done
# 3997  is done
# 3998  is done
# 3999  is done
# 4000  is done
# 4001  is done
# 4002  is done
# 4003  is done
# 4004  is done
# 4005  is done
# 4006  is done
# 4007  is done
# 4008  is done
# 4009  is done
# 4010  is done
# 4011  is done
# 4012  is done
# 4013  is done
# 4014  is done
# 4015  is done
# 4016  is done
# 4017  is done
# 4018  is done
# 4019  is done
# 4020  is done
# 4021  is done
# 4022  is done
# 4023  is done
# 4024  is done
# 4025  is done
# 4026  is done
# 4027  is done
# 4028  is done
# 4029  is done
# 4030  is done
# 4031  is done
# 4032  is done
# 4033  is done
# 4034  is done
# 4035  is done
# 4036  is done
# 4037  is done
# 4038  is done
# Copy Complete

# %%
def get_files_from_folder(path):

    files = os.listdir(path)
    return np.asarray(files)

def split(path_to_data, path_to_test_data, train_ratio):
    # get dirs
    _, dirs, _ = next(os.walk(path_to_data))

    # calculates how many train data per class
    data_counter_per_class = np.zeros((len(dirs)))
    for i in range(len(dirs)):
        path = os.path.join(path_to_data, dirs[i])
        files = get_files_from_folder(path)
        data_counter_per_class[i] = len(files)
    test_counter = np.round(data_counter_per_class * (1 - train_ratio))

    # transfers files
    for i in range(len(dirs)):
        path_to_original = os.path.join(path_to_data, dirs[i])
        path_to_save = os.path.join(path_to_test_data, dirs[i])

        #creates dir
        if not os.path.exists(path_to_save):
            os.makedirs(path_to_save)
        files = get_files_from_folder(path_to_original)
        # moves data
        for j in range(int(test_counter[i])):
            dst = os.path.join(path_to_save, files[j])
            src = os.path.join(path_to_original, files[j])
            shutil.move(src, dst)
    print('Done')

# %%
path_to_data = 'D:/Downloads/gta5/Compressed/covid_19_dataset_sorted/data/'
path_to_test_data = 'D:/Downloads/gta5/Compressed/covid_19_dataset_sorted/test_data/'
train_ratio = 0.8

# %%
split(path_to_data, path_to_test_data, train_ratio)
# Out:
# Done
